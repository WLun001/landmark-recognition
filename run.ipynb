# %%
import os
rootdir = './tf_files/test_images/'

for subdir, dirs, files in os.walk(rootdir):
    for index, file in enumerate(files):
        #print os.path.join(subdir, file)
        filepath = subdir + os.sep + file

        if filepath.endswith(".jpg"):
            filepath = filepath[2:]
            # %run scripts/label_image \
                --graph=tf_files/retrained_graph.pb  \
                --image="$filepath"
            print(str(index) + '/' + str(len(files)))
#         if i == 2:
#           break
            #print(filepath)
# Out:
# /home/wlun/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Evaluation time (1-image): 0.256s
#
# 9633 0.96265054
# 6599 0.026137935
# 6051 0.011211561
# 0/500
#
# Evaluation time (1-image): 0.252s
#
# 6599 0.978741
# 9633 0.021209935
# 6051 4.9147955e-05
# 1/500
#
# Evaluation time (1-image): 0.307s
#
# 9633 0.93409973
# 6051 0.05862857
# 6599 0.007271741
# 2/500
#
# Evaluation time (1-image): 0.314s
#
# 9633 0.9566758
# 6599 0.024112755
# 6051 0.01921149
# 3/500
#
# Evaluation time (1-image): 0.341s
#
# 9633 0.7472799
# 6599 0.19742101
# 6051 0.055299085
# 4/500
#
# Evaluation time (1-image): 0.235s
#
# 6599 0.9992029
# 9633 0.0004424746
# 6051 0.00035457296
# 5/500
#
# Evaluation time (1-image): 0.247s
#
# 9633 0.992065
# 6051 0.0044316193
# 6599 0.003503348
# 6/500
#
# Evaluation time (1-image): 0.305s
#
# 9633 0.99995065
# 6051 3.3315395e-05
# 6599 1.6009419e-05
# 7/500
#
# Evaluation time (1-image): 0.357s
#
# 9633 0.7084462
# 6599 0.29013884
# 6051 0.0014149748
# 8/500
#
# Evaluation time (1-image): 0.247s
#
# 6599 0.74918187
# 9633 0.2066492
# 6051 0.044168968
# 9/500
#
# Evaluation time (1-image): 0.256s
#
# 9633 0.61276996
# 6051 0.29939583
# 6599 0.08783423
# 10/500
#
# Evaluation time (1-image): 0.254s
#
# 9633 0.69539875
# 6599 0.27617908
# 6051 0.028422244
# 11/500
#
# Evaluation time (1-image): 0.253s
#
# 9633 0.6379679
# 6599 0.34277394
# 6051 0.019258127
# 12/500
#
# Evaluation time (1-image): 0.249s
#
# 9633 0.98578435
# 6051 0.009431076
# 6599 0.0047845603
# 13/500
#
# Evaluation time (1-image): 0.242s
#
# 9633 0.865815
# 6599 0.1188631
# 6051 0.01532187
# 14/500
#
# Evaluation time (1-image): 0.259s
#
# 9633 0.99215215
# 6051 0.0060733287
# 6599 0.0017744788
# 15/500
#
# Evaluation time (1-image): 0.244s
#
# 9633 0.98997176
# 6051 0.009719689
# 6599 0.00030854775
# 16/500
#
# Evaluation time (1-image): 0.247s
#
# 6599 0.956218
# 9633 0.040490314
# 6051 0.003291733
# 17/500
#
# Evaluation time (1-image): 0.244s
#
# 9633 0.8600612
# 6051 0.13987377
# 6599 6.504371e-05
# 18/500
#
# Evaluation time (1-image): 0.248s
#
# 6599 0.8646329
# 9633 0.13006344
# 6051 0.0053036427
# 19/500
#
# Evaluation time (1-image): 0.241s
#
# 9633 0.7856785
# 6051 0.20502463
# 6599 0.009296859
# 20/500
#
# Evaluation time (1-image): 0.248s
#
# 9633 0.9999114
# 6599 8.161902e-05
# 6051 7.0022516e-06
# 21/500
#
# Evaluation time (1-image): 0.244s
#
# 9633 0.98782724
# 6051 0.009270835
# 6599 0.0029019418
# 22/500
#
# Evaluation time (1-image): 0.249s
#
# 6599 0.53884774
# 9633 0.33877912
# 6051 0.122373134
# 23/500
#
# Evaluation time (1-image): 0.241s
#
# 9633 0.97601116
# 6051 0.023905538
# 6599 8.331292e-05
# 24/500
#
# Evaluation time (1-image): 0.244s
#
# 6599 0.44922078
# 6051 0.31977847
# 9633 0.23100072
# 25/500
#
# Evaluation time (1-image): 0.247s
#
# 9633 0.8713696
# 6051 0.124088675
# 6599 0.0045417496
# 26/500
#
# Evaluation time (1-image): 0.243s
#
# 6599 0.99747366
# 9633 0.002518648
# 6051 7.771707e-06
# 27/500
#
# Evaluation time (1-image): 0.242s
#
# 9633 0.9965917
# 6599 0.0023427566
# 6051 0.0010655553
# 28/500
#
# Evaluation time (1-image): 0.245s
#
# 6051 0.887187
# 9633 0.074027985
# 6599 0.038784944
# 29/500
#
# Evaluation time (1-image): 0.251s
#
# 6599 0.51291233
# 9633 0.4862103
# 6051 0.00087741
# 30/500
#
# Evaluation time (1-image): 0.246s
#
# 9633 0.8608211
# 6599 0.1361815
# 6051 0.0029973388
# 31/500
#
# Evaluation time (1-image): 0.254s
#
# 6599 0.9796592
# 9633 0.019996956
# 6051 0.00034377875
# 32/500
#
# Evaluation time (1-image): 0.247s
#
# 9633 0.8627198
# 6051 0.13685246
# 6599 0.00042777628
# 33/500
#
# Evaluation time (1-image): 0.248s
#
# 6599 0.95634264
# 9633 0.03410308
# 6051 0.009554337
# 34/500
#
# Evaluation time (1-image): 0.251s
#
# 9633 0.76415384
# 6599 0.22539212
# 6051 0.010454061
# 35/500
#
# Evaluation time (1-image): 0.250s
#
# 6599 0.9597249
# 9633 0.034882188
# 6051 0.0053928336
# 36/500
#
# Evaluation time (1-image): 0.240s
#
# 9633 0.987817
# 6051 0.011605887
# 6599 0.0005771198
# 37/500
#
# Evaluation time (1-image): 0.252s
#
# 9633 0.6090492
# 6599 0.3697802
# 6051 0.021170516
# 38/500
#
# Evaluation time (1-image): 0.238s
#
# 9633 0.9862932
# 6599 0.006928673
# 6051 0.006778157
# 39/500
#
# Evaluation time (1-image): 0.253s
#
# 9633 0.64162636
# 6599 0.35805959
# 6051 0.00031411144
# 40/500
#
# Evaluation time (1-image): 0.245s
#
# 6051 0.91208845
# 6599 0.08708717
# 9633 0.0008243427
# 41/500
#
# Evaluation time (1-image): 0.239s
#
# 9633 0.9843873
# 6599 0.015612282
# 6051 4.0088332e-07
# 42/500
#
# Evaluation time (1-image): 0.250s
#
# 6599 0.9999839
# 9633 1.4867955e-05
# 6051 1.1563642e-06
# 43/500
#
# Evaluation time (1-image): 0.258s
#
# 6599 0.9565066
# 9633 0.04252166
# 6051 0.0009717648
# 44/500
#
# Evaluation time (1-image): 0.291s
#
# 9633 0.9621475
# 6051 0.032619737
# 6599 0.0052327365
# 45/500
#
# Evaluation time (1-image): 0.255s
#
# 6051 0.98520154
# 9633 0.014084138
# 6599 0.0007143548
# 46/500
#
# Evaluation time (1-image): 0.273s
#
# 9633 0.579179
# 6599 0.33415958
# 6051 0.08666147
# 47/500
#
# Evaluation time (1-image): 0.248s
#
# 6051 0.9656745
# 9633 0.03367483
# 6599 0.0006506508
# 48/500
#
# Evaluation time (1-image): 0.250s
#
# 6051 0.92839247
# 9633 0.06937423
# 6599 0.002233308
# 49/500
#
# Evaluation time (1-image): 0.247s
#
# 6599 0.8755828
# 9633 0.10118225
# 6051 0.02323492
# 50/500
#
# Evaluation time (1-image): 0.244s
#
# 9633 0.6065491
# 6599 0.39221743
# 6051 0.0012335407
# 51/500
#
# Evaluation time (1-image): 0.251s
#
# 9633 0.99685967
# 6051 0.0016294778
# 6599 0.00151086
# 52/500
#
# Evaluation time (1-image): 0.242s
#
# 9633 0.9824654
# 6051 0.015198642
# 6599 0.0023359957
# 53/500
#
# Evaluation time (1-image): 0.249s
#
# 6599 0.69343495
# 9633 0.30525345
# 6051 0.0013116502
# 54/500
#
# Evaluation time (1-image): 0.252s
#
# 9633 0.8907527
# 6599 0.09354319
# 6051 0.015704144
# 55/500
#
# Evaluation time (1-image): 0.248s
#
# 6599 0.9976628
# 9633 0.002308987
# 6051 2.8187478e-05
# 56/500
#
# Evaluation time (1-image): 0.264s
#
# 6051 0.6314413
# 9633 0.366076
# 6599 0.0024827784
# 57/500
#
# Evaluation time (1-image): 0.248s
#
# 6051 0.75774056
# 9633 0.23772304
# 6599 0.004536328
# 58/500
#
# Evaluation time (1-image): 0.245s
#
# 6599 0.9945797
# 9633 0.0052119102
# 6051 0.00020846298
# 59/500
#
# Evaluation time (1-image): 0.248s
#
# 6599 0.87188274
# 9633 0.11619168
# 6051 0.011925523
# 60/500
#
# Evaluation time (1-image): 0.248s
#
# 9633 0.5993069
# 6599 0.40029538
# 6051 0.0003977645
# 61/500
#
# Evaluation time (1-image): 0.245s
#
# 6599 0.9742528
# 9633 0.025400152
# 6051 0.00034707767
# 62/500
#
# Evaluation time (1-image): 0.253s
#
# 6051 0.9693944
# 9633 0.03029756
# 6599 0.00030800205
# 63/500
#
# Evaluation time (1-image): 0.240s
#
# 9633 0.8231558
# 6599 0.16776201
# 6051 0.009082129
# 64/500
#
# Evaluation time (1-image): 0.249s
#
# 9633 0.68912697
# 6051 0.31048614
# 6599 0.00038692972
# 65/500
#
# Evaluation time (1-image): 0.248s
#
# 6051 0.5200892
# 6599 0.36124772
# 9633 0.11866305
# 66/500
#
# Evaluation time (1-image): 0.244s
#
# 9633 0.43897378
# 6599 0.37214395
# 6051 0.18888228
# 67/500
#
# Evaluation time (1-image): 0.247s
#
# 6599 0.8038761
# 9633 0.19482744
# 6051 0.0012965008
# 68/500
#
# Evaluation time (1-image): 0.256s
#
# 9633 0.79713476
# 6051 0.17726953
# 6599 0.025595644
# 69/500
#
# Evaluation time (1-image): 0.250s
#
# 9633 0.94304335
# 6599 0.033650074
# 6051 0.023306658
# 70/500
#
# Evaluation time (1-image): 0.249s
#
# 9633 0.9946853
# 6051 0.004627657
# 6599 0.0006870567
# 71/500
#
# Evaluation time (1-image): 0.243s
#
# 6599 0.98353666
# 9633 0.016443076
# 6051 2.0317493e-05
# 72/500
#
# Evaluation time (1-image): 0.243s
#
# 9633 0.9703518
# 6599 0.016120767
# 6051 0.013527365
# 73/500
#
# Evaluation time (1-image): 0.256s
#
# 9633 0.9654327
# 6599 0.022673663
# 6051 0.011893611
# 74/500
#
# Evaluation time (1-image): 0.246s
#
# 9633 0.73211384
# 6051 0.24844925
# 6599 0.019436872
# 75/500
#
# Evaluation time (1-image): 0.250s
#
# 9633 0.5975182
# 6051 0.3244849
# 6599 0.077996865
# 76/500
#
# Evaluation time (1-image): 0.257s
#
# 6599 0.88056886
# 9633 0.07455906
# 6051 0.044872105
# 77/500
#
# Evaluation time (1-image): 0.242s
#
# 6051 0.87213576
# 9633 0.12664738
# 6599 0.0012168514
# 78/500
#
# Evaluation time (1-image): 0.252s
#
# 6051 0.95356643
# 9633 0.046403848
# 6599 2.969696e-05
# 79/500
#
# Evaluation time (1-image): 0.256s
#
# 6599 0.9951481
# 9633 0.004559091
# 6051 0.00029281067
# 80/500
#
# Evaluation time (1-image): 0.241s
#
# 9633 0.8322963
# 6599 0.13869107
# 6051 0.029012637
# 81/500
#
# Evaluation time (1-image): 0.242s
#
# 6599 0.6889431
# 9633 0.30401292
# 6051 0.007043979
# 82/500
#
# Evaluation time (1-image): 0.257s
#
# 9633 0.98977715
# 6599 0.0101557365
# 6051 6.714293e-05
# 83/500
#
# Evaluation time (1-image): 0.245s
#
# 6051 0.5735238
# 6599 0.25964674
# 9633 0.16682944
# 84/500
#
# Evaluation time (1-image): 0.254s
#
# 9633 0.95800096
# 6599 0.041077714
# 6051 0.0009213589
# 85/500
#
# Evaluation time (1-image): 0.260s
#
# 6599 0.5459447
# 6051 0.29073632
# 9633 0.16331898
# 86/500
#
# Evaluation time (1-image): 0.252s
#
# 9633 0.989528
# 6599 0.010020175
# 6051 0.0004518637
# 87/500
#
# Evaluation time (1-image): 0.279s
#
# 9633 0.84497386
# 6599 0.15449725
# 6051 0.0005289337
# 88/500
# Evaluation time (1-image): 0.266s
#
# 6051 0.8604109
# 9633 0.09721318
# 6599 0.04237592
# 89/500
#
# Evaluation time (1-image): 0.312s
#
# 6599 0.9223958
# 6051 0.07586019
# 9633 0.001743927
# 90/500
#
# Evaluation time (1-image): 0.252s
#
# 9633 0.9330315
# 6599 0.06426725
# 6051 0.0027012362
# 91/500
#
# Evaluation time (1-image): 0.250s
#
# 6599 0.933932
# 6051 0.0342403
# 9633 0.031827614
# 92/500
#
# Evaluation time (1-image): 0.252s
#
# 9633 0.99937147
# 6599 0.00055727013
# 6051 7.133023e-05
# 93/500
#
# Evaluation time (1-image): 0.260s
#
# 9633 0.93934065
# 6051 0.060216207
# 6599 0.0004431411
# 94/500
#
# Evaluation time (1-image): 0.249s
#
# 6599 0.7737053
# 9633 0.22621296
# 6051 8.175861e-05
# 95/500
#
# Evaluation time (1-image): 0.303s
#
# 6599 0.60187566
# 9633 0.39364597
# 6051 0.004478462
# 96/500
#
# Evaluation time (1-image): 0.258s
#
# 6051 0.6214292
# 9633 0.37856886
# 6599 1.9892861e-06
# 97/500
#
# Evaluation time (1-image): 0.250s
#
# 9633 0.78092986
# 6599 0.21876857
# 6051 0.00030153515
# 98/500
#
# Evaluation time (1-image): 0.289s
#
# 9633 0.532012
# 6051 0.3109425
# 6599 0.15704554
# 99/500
#
# Evaluation time (1-image): 0.306s
#
# 9633 0.9922578
# 6599 0.007682417
# 6051 5.9792845e-05
# 100/500
#
# Evaluation time (1-image): 0.282s
#
# 6051 0.7016836
# 6599 0.17576036
# 9633 0.12255608
# 101/500
#
# Evaluation time (1-image): 0.262s
#
# 6599 0.92150646
# 9633 0.06801456
# 6051 0.010479007
# 102/500
#
# Evaluation time (1-image): 0.245s
#
# 9633 0.5148363
# 6599 0.2642935
# 6051 0.2208702
# 103/500
#
# Evaluation time (1-image): 0.257s
#
# 6051 0.99169475
# 9633 0.008204742
# 6599 0.00010049339
# 104/500
#
# Evaluation time (1-image): 0.261s
#
# 6051 0.99817073
# 9633 0.0016439883
# 6599 0.00018523676
# 105/500
#
# Evaluation time (1-image): 0.247s
#
# 9633 0.82879883
# 6051 0.1207527
# 6599 0.050448444
# 106/500
#
# Evaluation time (1-image): 0.259s
#
# 9633 0.985615
# 6599 0.01272516
# 6051 0.0016598351
# 107/500
#
# Evaluation time (1-image): 0.257s
#
# 6599 0.8554256
# 9633 0.12551793
# 6051 0.019056559
# 108/500
#
# Evaluation time (1-image): 0.253s
#
# 9633 0.6083163
# 6051 0.38893253
# 6599 0.0027511383
# 109/500
#
# Evaluation time (1-image): 0.256s
#
# 9633 0.90303224
# 6051 0.091114
# 6599 0.0058537973
# 110/500
#
# Evaluation time (1-image): 0.268s
#
# 9633 0.8866193
# 6599 0.112561524
# 6051 0.00081914425
# 111/500
#
# Evaluation time (1-image): 0.254s
#
# 6599 0.99993324
# 9633 5.7072903e-05
# 6051 9.615285e-06
# 112/500
